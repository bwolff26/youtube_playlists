# %% [markdown]
# Yeah, I'm already giving up... too crazy. Pragmatically, I should work on it though.

# %%
import pandas as pd
import googleapiclient.discovery

# %%
from currentsecrets import youtube_token, user_id, channel_id

# %%
# import gdata.youtube
# import gdata.youtube.service

# %%
# pip install --upgrade pytube

# %%
# pip install --upgrade google-api-python-client

# %%
#Mmk, now that we have our token time to actually do stuff.

# %%
youtube = googleapiclient.discovery.build("youtube"
                                         ,"v3"
                                         ,developerKey=youtube_token)

# %%
url = "https://www.youtube.com/playlist?list=PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK"

# %%
youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK").execute().values()
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '88tpZcOl-rknJ2t0sCSIkvAO7HU',
#  'nextPageToken': 'EAAajgFQVDpDQVVpRUVOQlEwUkVORFkyUWpORlJERTFOalVvQVVqdXM0N0o3b1dGQTFBQldrVWlRMmxLVVZSSGVHMVVNbEpNVld0VmVtRkhkRVZXVmtKVlducEtNVTF1WnpCU1ZFVTBWVEZHTkZaWVFsTmxXR2hNUldkM1NYQk9hbmh5ZDFsUmMwMVFWRFJCU1NJ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': '7DOpxKxr9JYO8MF-1ZCs3A6fLIs',
#    'id': 'UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy4wN0FDNkIxM0EwMDYxRkQy',
#    'snippet': {'publishedAt': '2023-08-30T03:16:46Z',
#     'channelId': 'UCXG_a0AQjAS7S1b_PQRdJeQ',
#     'title': 'アイのシナリオ／CHiCO with HoneyWorks',
# ...

# %%
npi = youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK").execute()['nextPageToken']
npi
# Out:
# 'EAAajgFQVDpDQVVpRUVOQlEwUkVORFkyUWpORlJERTFOalVvQVVqdXM0N0o3b1dGQTFBQldrVWlRMmxLVVZSSGVHMVVNbEpNVld0VmVtRkhkRVZXVmtKVlducEtNVTF1WnpCU1ZFVTBWVEZHTkZaWVFsTmxXR2hNUldkM1NYQk9hbmh5ZDFsUmMwMVFWRFJCU1NJ'

# %%
first_iter = youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK"
    ,maxResults=50).execute()
first_iter
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '5C5a_UQNoGMUe5Cl5h1QyyLN80k',
#  'nextPageToken': 'EAAajgFQVDpDRElpRURCQ01EaENSVVJEUkVWRVFqTXlNVUlvQVVqdXM0N0o3b1dGQTFBQldrVWlRMmxLVVZSSGVHMVVNbEpNVld0VmVtRkhkRVZXVmtKVlducEtNVTF1WnpCU1ZFVTBWVEZHTkZaWVFsTmxXR2hNUldkM1NYQk9hbmh5ZDFsUmMwMVFWRFJCU1NJ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': '7DOpxKxr9JYO8MF-1ZCs3A6fLIs',
#    'id': 'UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy4wN0FDNkIxM0EwMDYxRkQy',
#    'snippet': {'publishedAt': '2023-08-30T03:16:46Z',
#     'channelId': 'UCXG_a0AQjAS7S1b_PQRdJeQ',
#     'title': 'アイのシナリオ／CHiCO with HoneyWorks',
# ...

# %%
 'etag': '7DOpxKxr9JYO8MF-1ZCs3A6fLIs',
   'id': 'UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy4wN0FDNkIxM0EwMDYxRkQy',

# %%
npi = first_iter['nextPageToken']
npi
# Out:
# 'EAAajgFQVDpDRElpRURCQ01EaENSVVJEUkVWRVFqTXlNVUlvQVVqdXM0N0o3b1dGQTFBQldrVWlRMmxLVVZSSGVHMVVNbEpNVld0VmVtRkhkRVZXVmtKVlducEtNVTF1WnpCU1ZFVTBWVEZHTkZaWVFsTmxXR2hNUldkM1NYQk9hbmh5ZDFsUmMwMVFWRFJCU1NJ'

# %%
for i in range(len(first_iter['items'])):
    print(first_iter['items'][i]['snippet']['title'])
# Out:
# アイのシナリオ／CHiCO with HoneyWorks
# Deleted video
# [HD] Gosick Opening 1【GOSICK ゴシック OP】 『Destin Histoire』
# Re:Zero kara Hajimeru Isekai Seikatsu Ending FULL - Re：ゼロから始める異世界生活 ED 「STYX HELIX」
# Dusk maiden of Amnesia Opening Full [ Konomi Suzuki - Choir Jail ]
# Kimi ga Yume wo Tsuretekita
# Deleted video
# The Everlasting Guilty Crown [EGOIST] with Lyrics
# Fate Zero 2nd ending song
# Nisekoi ニセコイ Opening 1 Full「Click」
# ClariS - DROP (shooting star remix)
# Supercell / Ryo : 02. LOVE & ROLL
# Kimi no Shiranai Monogatari - Bakemonogatari 化物語 [Multi-Subtitles]
# Deleted video
# 【MV】 鹿乃 「Stella-rium」 【OFFICIAL】
# センチメンタルな愛慕心　歌いました【鹿乃】
# 【MV】 鹿乃 「Ivy」 【OFFICIAL】
# 【MV】鹿乃「春に落ちて」【OFFICIAL】
# 【俺妹】irony 自剪辑完整 MV 完整op
# Deleted video
# Deleted video
# シグナルグラフ　歌詞つき
# 『劇場版Fate/kaleid liner プリズマ☆イリヤ 雪下の誓い』主題歌「kaleidoscope」
# Nightcore–Process (Nakamura Meiko)
# Private video
# Violet Evergarden outro / Ending Full - "Michishirube" by Minori Chihara
# 【MAD】其の本物と【俺ガイル】
# ...

# %%
etags, ids, titles = [], [], []

npt = first_iter['nextPageToken']

for i in range(len(first_iter['items'])):
    etags.append(first_iter['items'][i]['etag'])
    ids.append(first_iter['items'][i]['id'])
    titles.append(first_iter['items'][i]['snippet']['title'])

# %%
iter_count = 1

# %%
#Awwwww yeah. We're getting their. So, the plan will be to get everything accumulated to one list then  make the df:

iter_count +=1
print({iter_count})


next_iter = youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK"
    ,maxResults=50
    ,pageToken=npt).execute()
# Out:
# {2}

# %%
npt = next_iter['nextPageToken']

for i in range(len(next_iter['items'])):
    etags.append(next_iter['items'][i]['etag'])
    ids.append(next_iter['items'][i]['id'])
    titles.append(next_iter['items'][i]['snippet']['title'])

print(len(titles))
# Out:
# 100

# %%
#Awww yeah Hmm, and now let's do this for a list of n length... 

#Guess we'll do it the boring way for now...
# Out:
# 'Nightcore - 葉桜 ♫(Lyrics)'

# %%
iter_count +=1
print({iter_count})


next_iter = youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK"
    ,maxResults=50
    ,pageToken=npt).execute()

npt = next_iter['nextPageToken']

for i in range(len(next_iter['items'])):
    etags.append(next_iter['items'][i]['etag'])
    ids.append(next_iter['items'][i]['id'])
    titles.append(next_iter['items'][i]['snippet']['title'])

print(len(titles))
# Out:
# {3}
# 150

# %%
iter_count +=1
print({iter_count})


next_iter = youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK"
    ,maxResults=50
    ,pageToken=npt).execute()

npt = next_iter['nextPageToken']

for i in range(len(next_iter['items'])):
    etags.append(next_iter['items'][i]['etag'])
    ids.append(next_iter['items'][i]['id'])
    titles.append(next_iter['items'][i]['snippet']['title'])

print(len(titles))
# Out:
# {4}
# 200

# %%
iter_count +=1
print({iter_count})


next_iter = youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK"
    ,maxResults=50
    ,pageToken=npt).execute()

npt = next_iter['nextPageToken']

for i in range(len(next_iter['items'])):
    etags.append(next_iter['items'][i]['etag'])
    ids.append(next_iter['items'][i]['id'])
    titles.append(next_iter['items'][i]['snippet']['title'])

print(len(titles))
# Out:
# {5}
# 250

# %%
iter_count +=1
print({iter_count})


next_iter = youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK"
    ,maxResults=50
    ,pageToken=npt).execute()

npt = next_iter['nextPageToken']

for i in range(len(next_iter['items'])):
    etags.append(next_iter['items'][i]['etag'])
    ids.append(next_iter['items'][i]['id'])
    titles.append(next_iter['items'][i]['snippet']['title'])

print(len(titles))
# Out:
# {6}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 11
#       2 print({iter_count})
#       5 next_iter = youtube.playlistItems().list(
#       6     part = 'snippet'
#       7     ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK"
#       8     ,maxResults=50
#       9     ,pageToken=npt).execute()
# ---> 11 npt = next_iter['nextPageToken']
#      13 for i in range(len(next_iter['items'])):
#      14     etags.append(next_iter['items'][i]['etag'])
#
# KeyError: 'nextPageToken'

# %%
for i in range(len(next_iter['items'])):
    etags.append(next_iter['items'][i]['etag'])
    ids.append(next_iter['items'][i]['id'])
    titles.append(next_iter['items'][i]['snippet']['title'])

print(len(titles))
# Out:
# 294

# %%
#Yeah.... sure enough 'nextPageToken' just won't appear.... anyways, let's finish this one first:

# %%
df = pd.DataFrame({
    'titles':titles
    ,'etags':etags
    ,'ids':ids
})

# %%
df.head()
# Out:
#                                               titles  \
# 0                      アイのシナリオ／CHiCO with HoneyWorks
# 1                                      Deleted video
# 2  [HD] Gosick Opening 1【GOSICK ゴシック OP】 『Destin ...
# 3  Re:Zero kara Hajimeru Isekai Seikatsu Ending F...
# 4  Dusk maiden of Amnesia Opening Full [ Konomi S...
#
#                          etags  \
# 0  7DOpxKxr9JYO8MF-1ZCs3A6fLIs
# 1  F4i9MnBa3jikQoSFurruAjXEOrY
# 2  rhf0m67ZxFBhXIe7Dywqsd_wGCg
# 3  2z6AqCn_O0gvUi1u3QfpNU2Wza8
# 4  NOp6gme5aFg_Zj4buRGpV_TtjH0
#
#                                                  ids
# 0  UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy...
# 1  UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy...
# 2  UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy...
# 3  UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy...
# 4  UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy...

# %%
len(df['etags'].unique()) #Should be def, as you shouldn't be allowed to hav multiple copies of hte same video in a playlist.
# Out:
# 294

# %%
df['titles'].value_counts().head()  #Yeah, so that's what we need to focus onn - the 'Deleted video' as well as the 'Private video'
# Out:
# titles
# Deleted video                       10
# Private video                        4
# Himegoto Lips                        2
# Nightcore - Miracle                  1
# [Nightcore] Kana Nishino - Honey     1
# Name: count, dtype: int64

# %% [markdown]
# ## Generalizing
#
# Now that we finally have the basics down, let's make the code spifier to get everything at once.

# %%
etags, ids, titles = [], [], []

npt = ''
playlist_id = 'PLlfOdKRE3hkCL8RWybF7ODd7iS1rfFcYU' #Ie the guy that starts in the url 'Pl'
#,which should be after 'playlist?list='

while npt != 'done'
next_iter = youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId=playlist_id
    ,maxResults=50
    ,pageToken=npt).execute()

try:
    npt = next_iter['nextPageToken']
except:
    npt = False
    
for i in range(len(next_iter['items'])):
    etags.append(next_iter['items'][i]['etag'])
    ids.append(next_iter['items'][i]['id'])
    titles.append(next_iter['items'][i]['snippet']['title'])

print(len(titles))

# %%
next_iter
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '77sFt2YFVap1QQWOZQYlCWHvulQ',
#  'prevPageToken': 'EAEajwFQVDpDUG9CSWhBM01EQTFOMFUxTUVKR1JqZEROelV4S0FGSTdyT095ZTZGaFFOUUFGcEZJa05wU2xGVVIzaHRWREpTVEZWclZYcGhSM1JGVmxaQ1ZWcDZTakZOYm1jd1VsUkZORlV4UmpSV1dFSlRaVmhvVEVWbmQwbHdUbXA0Y25kWlVYTk5VRlEwUVVraQ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'XDgG-LCs_JiPr2-ovmPUT7HgBwk',
#    'id': 'UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy43MDA1N0U1MEJGRjdDNzUx',
#    'snippet': {'publishedAt': '2023-11-28T02:31:59Z',
#     'channelId': 'UCXG_a0AQjAS7S1b_PQRdJeQ',
#     'title': 'Kaguya-Sama: Love is War Season 2 Ending Full - 『Kaze ni Fukarete』by Haruka Fukuhara',
# ...

# %%
if first_iter['pageInfo']['totalResults'] % 50 == 0:
    reps = first_iter['pageInfo']['totalResults']/50
else:
    reps = (first_iter['pageInfo']['totalResults']//50) + 1
reps
# Out:
# 6

# %%
iter_count +=1
print({iter_count})


next_iter = youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK"
    ,maxResults=50
    ,pageToken=npt).execute()

npt = next_iter['nextPageToken']

for i in range(len(next_iter['items'])):
    etags.append(next_iter['items'][i]['etag'])
    ids.append(next_iter['items'][i]['id'])
    titles.append(next_iter['items'][i]['snippet']['title'])

print(len(titles))

# %%
next_iter
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '2jo4Xnh5lUtx5_am2xGeLKu5Ps0',
#  'nextPageToken': 'EAAajgFQVDpDR1FpRUVWRU56UkNSREV6T1VReE5rRXpPRFFvQVVqdXM0N0o3b1dGQTFBQldrVWlRMmxLVVZSSGVHMVVNbEpNVld0VmVtRkhkRVZXVmtKVlducEtNVTF1WnpCU1ZFVTBWVEZHTkZaWVFsTmxXR2hNUldkM1NYQk9hbmh5ZDFsUmMwMVFWRFJCU1NJ',
#  'prevPageToken': 'EAEajgFQVDpDRElpRURCQ01EaENSVVJEUkVWRVFqTXlNVUlvQVVqdXM0N0o3b1dGQTFBQVdrVWlRMmxLVVZSSGVHMVVNbEpNVld0VmVtRkhkRVZXVmtKVlducEtNVTF1WnpCU1ZFVTBWVEZHTkZaWVFsTmxXR2hNUldkM1NYQk9hbmh5ZDFsUmMwMVFWRFJCU1NJ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': '7Ke0rdKBrnKTO6P_OIudG7fcfBA',
#    'id': 'UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy4wQjA4QkVEQ0RFREIzMjFC',
#    'snippet': {'publishedAt': '2020-07-10T13:03:11Z',
#     'channelId': 'UCXG_a0AQjAS7S1b_PQRdJeQ',
#     'title': 'CHiCO with HoneyWorks- 「Wolf(ウルフ)」Full',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zIJYM8OupQo/default.jpg',
#       'width': 120,
# ...

# %%
first_iter['items'][-1]
# Out:
# {'kind': 'youtube#playlistItem',
#  'etag': 'nf3yYqd54cVOTbzTws37bdMItDk',
#  'id': 'UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy41QTQ4QTIyM0Y1RTBGMUNE',
#  'snippet': {'publishedAt': '2020-07-08T18:25:45Z',
#   'channelId': 'UCXG_a0AQjAS7S1b_PQRdJeQ',
#   'title': '┗|∵|┓ミスター・ダーリン／HoneyWorks feat.初音ミク',
#   'description': 'ミスター・ダーリン／CHiCO with HoneyWorks meets 中川翔子\nのボカロcoverです。\n\nCHiCO with HoneyWorks 10th Single\n「ミスター・ダーリン／ギミギミコール」\n2018年11月7日発売\n\n＜CHiCO with HoneyWorks meets 中川翔子盤＞\n▶Amazon\u3000http://amzn.asia/d/82aqMBe\n＜CHiCO with HoneyWorks meets スカイピース盤＞\n▶Amazon\u3000http://amzn.asia/d/7XI1yYS\n\n◆ボーカル：初音ミク\n\n◆作編曲：HoneyWorks\n\n◆ギター：中西\n◆ベース：shito\n◆ピアノ：cake\n◆ドラム：裕木レオン\n◆ストリングスアレンジ：堤 博明\n◆ストリングス：門脇大輔ストリングス\n\n■イラスト：ヤマコ\n■ロゴ、動画：モゲラッタ\n\n■スペシャルサンクス：桐谷\n\nカラオケ→https://com.nicovideo.jp/community/co474645',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L8s6349tDKs/default.jpg',
#     'width': 120,
#     'height': 90},
# ...

# %%
first_iter['items'][0]
# Out:
# {'kind': 'youtube#playlistItem',
#  'etag': '7DOpxKxr9JYO8MF-1ZCs3A6fLIs',
#  'id': 'UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy4wN0FDNkIxM0EwMDYxRkQy',
#  'snippet': {'publishedAt': '2023-08-30T03:16:46Z',
#   'channelId': 'UCXG_a0AQjAS7S1b_PQRdJeQ',
#   'title': 'アイのシナリオ／CHiCO with HoneyWorks',
# ...

# %%
i = -1

# %%
list(youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK").execute().values())[3][0]
# Out:
# {'kind': 'youtube#playlistItem',
#  'etag': '7DOpxKxr9JYO8MF-1ZCs3A6fLIs',
#  'id': 'UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy4wN0FDNkIxM0EwMDYxRkQy',
#  'snippet': {'publishedAt': '2023-08-30T03:16:46Z',
#   'channelId': 'UCXG_a0AQjAS7S1b_PQRdJeQ',
#   'title': 'アイのシナリオ／CHiCO with HoneyWorks',
# ...

# %%
list(youtube.playlistItems().list(
    part = 'snippet'
    ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK").execute().values())[3][0]['title']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 list(youtube.playlistItems().list(
#       2     part = 'snippet'
#       3     ,playlistId="PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK").execute().values())[3][0]['title']
#
# KeyError: 'title'

# %%
test = {'kind': 'youtube#playlistItem',
 'etag': '7DOpxKxr9JYO8MF-1ZCs3A6fLIs',
 'id': 'UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy4wN0FDNkIxM0EwMDYxRkQy',
 'snippet': {'publishedAt': '2023-08-30T03:16:46Z',
  'channelId': 'UCXG_a0AQjAS7S1b_PQRdJeQ',
  'title': 'アイのシナリオ／CHiCO with HoneyWorks',
  'description': '11月18日、CHiCO with HoneyHorks、待望のファースト・アルバム発売決定！\n\n今作には、Music Videoの世界観と内容が話題を呼び、YouTubeでの再生回数が1,800万回を超え、スマッシュヒットしたデビューシングル「世界は恋に落ちている」＜TVアニメ「アオハライド」OPテーマ＞や、TVアニメ「まじっく快斗1412」OPテーマの「アイのシナリオ」、更にTVアニメ「銀魂」OPテーマ「プライド革命」と超人気アニメタイアップ楽曲3曲が収録。さらにHoneyWorks書きおろしの新曲＋カバー楽曲と内容ももりだくさんだ。\n\nデビューから1年、『世界は恋に落ちている』『アイのシナリオ』『プライド革命』のMusicVIdeo合計総再生回数3000万回突破！まさに集大成と言えるファースト・アルバム！\nまた、初回限定盤には上記の超人気アニメタイアップ楽曲のシングル3曲+今回のデビュー・アルバムのリードトラックのMVなどが収録されたDVDや、デビュー・シングル「世界は恋に落ちている」のプロローグ編をモチーフにした100P（予定）のライトノベルが同梱されるなど、ファンにはたまらない内容となっている。\n\n【初回生産限定盤】\n＜CD＋DVD＋ライトノベル＞\nhttp://goo.gl/jKLVgI\n\n【通常盤】\n＜CDのみ＞\nhttp://goo.gl/4pBlGe\n\n▼CHiCO with HoneyWorks公式LINE\n・友だち追加・登録方法\u3000お持ちのスマートフォンにLINEアプリをダウンロード\n①その他 → 公式アカウント → アーティスト → CHiCO with HoneyWorks → 追加 \n②その他 → 友だち追加 → ID検索して追加 @chicowithhoneyworks\n③以下のリンク先から友だち追加 https://line.me/ti/p/%40chicowithhoneyworks\n\nhttp://www.sonymusic.co.jp/artist/chico/\niTunes：https://itunes.apple.com/jp/album/ainoshinario-tv-size-single/id952611214\nレコチョク：http://recochoku.jp/song/S1001096366/\nMora：http://mora.jp/package/43000001/4580163593961/\n\n全国区オーディション「ウタカツ！」 グランプリ【CHiCO】と【HoneyWorks】のコラボ・ユニット。2014年8月デビューシングル「世界は恋に落ちている」（アニメ「アオハライド」OPテーマ）がYouTube再生回数850万回再生超え、ニコニコ動画85万回再生と驚愕の再生数で衝撃のデビューを果たしたCHiCO with HoneyWorks。待望の2ndシングル「アイのシナリオ」（TVアニメ「まじっく快斗1412」OPテーマ）は疾走感と爽快感あるロックナンバー。C/Wの「ユキドケ」はヴォーカリストCHiCOの新たな一面を体感できる初のミディアムなナンバー。ハニワ制作の動画も必見です！',
  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/P_At3pIE5BU/default.jpg',
    'width': 120,
    'height': 90},
   'medium': {'url': 'https://i.ytimg.com/vi/P_At3pIE5BU/mqdefault.jpg',
    'width': 320,
    'height': 180},
   'high': {'url': 'https://i.ytimg.com/vi/P_At3pIE5BU/hqdefault.jpg',
    'width': 480,
    'height': 360},
   'standard': {'url': 'https://i.ytimg.com/vi/P_At3pIE5BU/sddefault.jpg',
    'width': 640,
    'height': 480},
   'maxres': {'url': 'https://i.ytimg.com/vi/P_At3pIE5BU/maxresdefault.jpg',
    'width': 1280,
    'height': 720}},
  'channelTitle': 'Joseph Fox',
  'playlistId': 'PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK',
  'position': 0,
  'resourceId': {'kind': 'youtube#video', 'videoId': 'P_At3pIE5BU'},
  'videoOwnerChannelTitle': 'Sony Music (Japan)',
  'videoOwnerChannelId': 'UCCy_q-N7F2FOIZ6ZggHIAKg'}}

# %%
test.items()
# Out:
# dict_items([('kind', 'youtube#playlistItem'), ('etag', '7DOpxKxr9JYO8MF-1ZCs3A6fLIs'), ('id', 'UExsZk9kS1JFM2hrRFVQVGcydTJ4NEUxOFNReFVwUnl4Sy4wN0FDNkIxM0EwMDYxRkQy'), ('snippet', {'publishedAt': '2023-08-30T03:16:46Z', 'channelId': 'UCXG_a0AQjAS7S1b_PQRdJeQ', 'title': 'アイのシナリオ／CHiCO with HoneyWorks', 'description': '11月18日、CHiCO with HoneyHorks、待望のファースト・アルバム発売決定！\n\n今作には、Music Videoの世界観と内容が話題を呼び、YouTubeでの再生回数が1,800万回を超え、スマッシュヒットしたデビューシングル「世界は恋に落ちている」＜TVアニメ「アオハライド」OPテーマ＞や、TVアニメ「まじっく快斗1412」OPテーマの「アイのシナリオ」、更にTVアニメ「銀魂」OPテーマ「プライド革命」と超人気アニメタイアップ楽曲3曲が収録。さらにHoneyWorks書きおろしの新曲＋カバー楽曲と内容ももりだくさんだ。\n\nデビューから1年、『世界は恋に落ちている』『アイのシナリオ』『プライド革命』のMusicVIdeo合計総再生回数3000万回突破！まさに集大成と言えるファースト・アルバム！\nまた、初回限定盤には上記の超人気アニメタイアップ楽曲のシングル3曲+今回のデビュー・アルバムのリードトラックのMVなどが収録されたDVDや、デビュー・シングル「世界は恋に落ちている」のプロローグ編をモチーフにした100P（予定）のライトノベルが同梱されるなど、ファンにはたまらない内容となっている。\n\n【初回生産限定盤】\n＜CD＋DVD＋ライトノベル＞\nhttp://goo.gl/jKLVgI\n\n【通常盤】\n＜CDのみ＞\nhttp://goo.gl/4pBlGe\n\n▼CHiCO with HoneyWorks公式LINE\n・友だち追加・登録方法\u3000お持ちのスマートフォンにLINEアプリをダウン
# ...

# %%
test['snippet']['title']
# Out:
# 'アイのシナリオ／CHiCO with HoneyWorks'

# %%
url = "https://www.youtube.com/playlist?list=PLlfOdKRE3hkDUPTg2u2x4E18SQxUpRyxK"
